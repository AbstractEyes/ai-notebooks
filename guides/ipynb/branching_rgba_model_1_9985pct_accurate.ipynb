# %% [markdown]
# # The Sequential model
#
# **Author:** [fchollet](https://twitter.com/fchollet)<br>
# **Date created:** 2020/04/12<br>
# **Last modified:** 2023/06/25<br>
# **Description:** Complete guide to the Sequential model that does not work. The outcome is because the test images were combined with the training images, causing false positives.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence, to_categorical
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import ModelCheckpoint

model = None

# %%
class SimpleCIFAR10DataGenerator(Sequence):
    def __init__(self, images, labels, batch_size=32, num_classes=10, shuffle=True):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.indices = np.arange(len(self.images))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_images = self.images[batch_indices]
        batch_labels = self.labels[batch_indices]

        batch_labels_onehot = to_categorical(batch_labels, num_classes=self.num_classes)
        return batch_images, batch_labels_onehot

def create_large_model(num_classes=10):
    rgb_input = layers.Input(shape=(32, 32, 3), name="rgb_input")

    def alpha_output_shape(input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 1)
    alpha = layers.Lambda(lambda x: tf.ones_like(x[..., :1]),
                          output_shape=alpha_output_shape, name="alpha_creation")(rgb_input)
    rgba = layers.Concatenate(axis=-1, name="rgba_concat")([rgb_input, alpha])

    def pair_output_shape(input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 2)
    def triplet_output_shape(input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 3)
    def quad_output_shape(input_shape):
        return (input_shape[0], input_shape[1], input_shape[2], 4)

    # For pairs that do not reorder channels, direct indexing might still fail, so let's use tf.gather everywhere for consistency:
    # rg: [0,1]
    rg = layers.Lambda(lambda x: tf.gather(x, [0,1], axis=-1), output_shape=pair_output_shape, name="rg_extract")(rgba)
    rb = layers.Lambda(lambda x: tf.gather(x, [0,2], axis=-1), output_shape=pair_output_shape, name="rb_extract")(rgba)
    gb = layers.Lambda(lambda x: tf.gather(x, [1,2], axis=-1), output_shape=pair_output_shape, name="gb_extract")(rgba)
    ra = layers.Lambda(lambda x: tf.gather(x, [0,3], axis=-1), output_shape=pair_output_shape, name="ra_extract")(rgba)
    ga = layers.Lambda(lambda x: tf.gather(x, [1,3], axis=-1), output_shape=pair_output_shape, name="ga_extract")(rgba)
    ba = layers.Lambda(lambda x: tf.gather(x, [2,3], axis=-1), output_shape=pair_output_shape, name="ba_extract")(rgba)
    rba= layers.Lambda(lambda x: tf.gather(x, [0,2,3], axis=-1), output_shape=triplet_output_shape, name="rba_extract")(rgba)
    rga= layers.Lambda(lambda x: tf.gather(x, [0,1,3], axis=-1), output_shape=triplet_output_shape, name="rga_extract")(rgba)
    bga= layers.Lambda(lambda x: tf.gather(x, [2,1,3], axis=-1), output_shape=triplet_output_shape, name="bga_extract")(rgba)
    rgb= layers.Lambda(lambda x: tf.gather(x, [0,1,2,3], axis=-1), output_shape=quad_output_shape, name="rgba_extract")(rgba)

    # Flatten all
    rg_flat = layers.Flatten(name="rg_flat")(rg)
    rb_flat = layers.Flatten(name="rb_flat")(rb)
    gb_flat = layers.Flatten(name="gb_flat")(gb)
    ra_flat = layers.Flatten(name="ra_flat")(ra)
    ga_flat = layers.Flatten(name="ga_flat")(ga)
    ba_flat = layers.Flatten(name="ba_flat")(ba)
    rba_flat= layers.Flatten(name="rba_flat")(rba)
    rga_flat= layers.Flatten(name="rga_flat")(rga)
    bga_flat= layers.Flatten(name="bga_flat")(bga)
    rgba_flat= layers.Flatten(name="rgba_flat")(rgb)
    rgba_flat= layers.LayerNormalization(name="rgba_norm")(rgba_flat)

    def process_subset(name, input_tensor):
        x = layers.Dense(256, activation='relu', name=f"{name}_dense_1")(input_tensor)
        x = layers.Dense(128, activation='relu', name=f"{name}_dense_2")(x)
        return x

    rg_proc = process_subset("rg", rg_flat)
    rb_proc = process_subset("rb", rb_flat)
    gb_proc = process_subset("gb", gb_flat)
    ra_proc = process_subset("ra", ra_flat)
    ga_proc = process_subset("ga", ga_flat)
    ba_proc = process_subset("ba", ba_flat)
    rba_proc= process_subset("rba", rba_flat)
    rga_proc= process_subset("rga", rga_flat)
    bga_proc= process_subset("bga", bga_flat)
    rgba_proc= process_subset("rgba", rgba_flat)

    concatenated = layers.Concatenate(name="color_concatenation")([
        rg_proc, rb_proc, gb_proc, ra_proc, ga_proc, ba_proc, rba_proc, rga_proc, bga_proc, rgba_flat
    ])

    x = layers.Dense(512, activation='relu', name="final_dense_1")(concatenated)
    x = layers.Dense(256, activation='relu', name="final_dense_2")(x)
    output = layers.Dense(num_classes, activation='softmax', name="output")(x)

    model = models.Model(inputs=rgb_input, outputs=output)
    return model

# %%
model = None

# %%
# load the model
model = models.load_model("best_model.keras")

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.cifar10.load_data()
images = np.concatenate([train_images, test_images], axis=0)
labels = np.concatenate([train_labels, test_labels], axis=0)

# %%
batch_size = 128


train_generator = SimpleCIFAR10DataGenerator(
    images=images,
    labels=labels,
    batch_size=batch_size,
    num_classes=10,
    shuffle=True
)

val_generator = SimpleCIFAR10DataGenerator(
    images=test_images,
    labels=test_labels,
    batch_size=batch_size,
    num_classes=10,
    shuffle=False
)

if model is None:
  print("creating large model")
  model = create_large_model(num_classes=10)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
#model.summary()

# ModelCheckpoint callback: save the best model based on validation loss
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.keras',    # file to save the best model
    monitor='val_loss',          # metric to monitor
    save_best_only=True,         # only save when val_loss improves
    save_weights_only=False,     # save the entire model, not just weights
    mode='min',                  # looking for minimum val_loss
    verbose=1
)
model.summary()
model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=500,
    batch_size=batch_size,
    callbacks=[checkpoint_callback],

    verbose=1
)

#main()
# Out:
# creating large model
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ rgb_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ alpha_creation (Lambda)   │ (None, 32, 32, 1)      │              0 │ rgb_input[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_concat (Concatenate) │ (None, 32, 32, 4)      │              0 │ rgb_input[0][0],       │
# │                           │                        │                │ alpha_creation[0][0]   │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_extract (Lambda)       │ (None, 32, 32, 2)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_extract (Lambda)      │ (None, 32, 32, 3)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_extract (Lambda)      │ (None, 32, 32, 3)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_extract (Lambda)      │ (None, 32, 32, 3)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_flat (Flatten)         │ (None, 2048)           │              0 │ rg_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_flat (Flatten)         │ (None, 2048)           │              0 │ rb_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_flat (Flatten)         │ (None, 2048)           │              0 │ gb_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_flat (Flatten)         │ (None, 2048)           │              0 │ ra_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_flat (Flatten)         │ (None, 2048)           │              0 │ ga_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_flat (Flatten)         │ (None, 2048)           │              0 │ ba_extract[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_flat (Flatten)        │ (None, 3072)           │              0 │ rba_extract[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_flat (Flatten)        │ (None, 3072)           │              0 │ rga_extract[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_flat (Flatten)        │ (None, 3072)           │              0 │ bga_extract[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_extract (Lambda)     │ (None, 32, 32, 4)      │              0 │ rgba_concat[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_1 (Dense)        │ (None, 256)            │        524,544 │ rg_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_1 (Dense)        │ (None, 256)            │        524,544 │ rb_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_1 (Dense)        │ (None, 256)            │        524,544 │ gb_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_1 (Dense)        │ (None, 256)            │        524,544 │ ra_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_1 (Dense)        │ (None, 256)            │        524,544 │ ga_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_1 (Dense)        │ (None, 256)            │        524,544 │ ba_flat[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_dense_1 (Dense)       │ (None, 256)            │        786,688 │ rba_flat[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_dense_1 (Dense)       │ (None, 256)            │        786,688 │ rga_flat[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_dense_1 (Dense)       │ (None, 256)            │        786,688 │ bga_flat[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_flat (Flatten)       │ (None, 4096)           │              0 │ rgba_extract[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_2 (Dense)        │ (None, 128)            │         32,896 │ rg_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_2 (Dense)        │ (None, 128)            │         32,896 │ rb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_2 (Dense)        │ (None, 128)            │         32,896 │ gb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_2 (Dense)        │ (None, 128)            │         32,896 │ ra_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_2 (Dense)        │ (None, 128)            │         32,896 │ ga_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_2 (Dense)        │ (None, 128)            │         32,896 │ ba_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_dense_2 (Dense)       │ (None, 128)            │         32,896 │ rba_dense_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_dense_2 (Dense)       │ (None, 128)            │         32,896 │ rga_dense_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_dense_2 (Dense)       │ (None, 128)            │         32,896 │ bga_dense_1[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_norm                 │ (None, 4096)           │          8,192 │ rgba_flat[0][0]        │
# │ (LayerNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ color_concatenation       │ (None, 5248)           │              0 │ rg_dense_2[0][0],      │
# │ (Concatenate)             │                        │                │ rb_dense_2[0][0],      │
# │                           │                        │                │ gb_dense_2[0][0],      │
# │                           │                        │                │ ra_dense_2[0][0],      │
# │                           │                        │                │ ga_dense_2[0][0],      │
# │                           │                        │                │ ba_dense_2[0][0],      │
# │                           │                        │                │ rba_dense_2[0][0],     │
# │                           │                        │                │ rga_dense_2[0][0],     │
# │                           │                        │                │ bga_dense_2[0][0],     │
# │                           │                        │                │ rgba_norm[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ final_dense_1 (Dense)     │ (None, 512)            │      2,687,488 │ color_concatenation[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ final_dense_2 (Dense)     │ (None, 256)            │        131,328 │ final_dense_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output (Dense)            │ (None, 10)             │          2,570 │ final_dense_2[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 8,632,970 (32.93 MB)
#  Trainable params: 8,632,970 (32.93 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2238 - loss: 56.3663
# Epoch 1: val_loss improved from inf to 1.72048, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.2240 - loss: 56.2779 - val_accuracy: 0.4005 - val_loss: 1.7205
# Epoch 2/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3881 - loss: 1.7580
# Epoch 2: val_loss improved from 1.72048 to 1.61159, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.3883 - loss: 1.7572 - val_accuracy: 0.4252 - val_loss: 1.6116
# Epoch 3/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4273 - loss: 1.6239
# Epoch 3: val_loss improved from 1.61159 to 1.54598, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4275 - loss: 1.6234 - val_accuracy: 0.4531 - val_loss: 1.5460
# Epoch 4/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4542 - loss: 1.5410
# Epoch 4: val_loss improved from 1.54598 to 1.46626, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4543 - loss: 1.5408 - val_accuracy: 0.4850 - val_loss: 1.4663
# Epoch 5/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4750 - loss: 1.4943
# Epoch 5: val_loss improved from 1.46626 to 1.42580, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4750 - loss: 1.4942 - val_accuracy: 0.4920 - val_loss: 1.4258
# Epoch 6/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.4939 - loss: 1.4386
# Epoch 6: val_loss improved from 1.42580 to 1.41835, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.4939 - loss: 1.4386 - val_accuracy: 0.4963 - val_loss: 1.4183
# Epoch 7/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5010 - loss: 1.4127
# Epoch 7: val_loss improved from 1.41835 to 1.33628, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5010 - loss: 1.4127 - val_accuracy: 0.5265 - val_loss: 1.3363
# Epoch 8/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5150 - loss: 1.3760
# Epoch 8: val_loss improved from 1.33628 to 1.31123, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5150 - loss: 1.3760 - val_accuracy: 0.5355 - val_loss: 1.3112
# Epoch 9/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5254 - loss: 1.3365
# Epoch 9: val_loss improved from 1.31123 to 1.29457, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5254 - loss: 1.3367 - val_accuracy: 0.5461 - val_loss: 1.2946
# Epoch 10/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5371 - loss: 1.3099
# Epoch 10: val_loss improved from 1.29457 to 1.27187, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5371 - loss: 1.3100 - val_accuracy: 0.5500 - val_loss: 1.2719
# Epoch 11/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5436 - loss: 1.2807
# Epoch 11: val_loss improved from 1.27187 to 1.24129, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5435 - loss: 1.2808 - val_accuracy: 0.5628 - val_loss: 1.2413
# Epoch 12/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5591 - loss: 1.2429
# Epoch 12: val_loss improved from 1.24129 to 1.20689, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5590 - loss: 1.2432 - val_accuracy: 0.5732 - val_loss: 1.2069
# Epoch 13/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5658 - loss: 1.2240
# Epoch 13: val_loss improved from 1.20689 to 1.14450, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5658 - loss: 1.2240 - val_accuracy: 0.5955 - val_loss: 1.1445
# Epoch 14/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5821 - loss: 1.1802
# Epoch 14: val_loss did not improve from 1.14450
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.5820 - loss: 1.1805 - val_accuracy: 0.5903 - val_loss: 1.1566
# Epoch 15/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5920 - loss: 1.1447
# Epoch 15: val_loss improved from 1.14450 to 1.11135, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5919 - loss: 1.1450 - val_accuracy: 0.6054 - val_loss: 1.1114
# Epoch 16/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5999 - loss: 1.1266
# Epoch 16: val_loss improved from 1.11135 to 1.09675, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.5998 - loss: 1.1268 - val_accuracy: 0.6076 - val_loss: 1.0967
# Epoch 17/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6127 - loss: 1.0964
# Epoch 17: val_loss improved from 1.09675 to 1.05343, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6126 - loss: 1.0966 - val_accuracy: 0.6274 - val_loss: 1.0534
# Epoch 18/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6232 - loss: 1.0584
# Epoch 18: val_loss improved from 1.05343 to 1.01808, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6231 - loss: 1.0587 - val_accuracy: 0.6388 - val_loss: 1.0181
# Epoch 19/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6330 - loss: 1.0292
# Epoch 19: val_loss improved from 1.01808 to 0.94445, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6329 - loss: 1.0294 - val_accuracy: 0.6639 - val_loss: 0.9444
# Epoch 20/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6489 - loss: 0.9873
# Epoch 20: val_loss did not improve from 0.94445
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.6488 - loss: 0.9875 - val_accuracy: 0.6518 - val_loss: 0.9643
# Epoch 21/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6560 - loss: 0.9684
# Epoch 21: val_loss improved from 0.94445 to 0.91048, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6559 - loss: 0.9684 - val_accuracy: 0.6768 - val_loss: 0.9105
# Epoch 22/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6723 - loss: 0.9195
# Epoch 22: val_loss improved from 0.91048 to 0.87244, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6721 - loss: 0.9201 - val_accuracy: 0.6900 - val_loss: 0.8724
# Epoch 23/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6821 - loss: 0.8932
# Epoch 23: val_loss improved from 0.87244 to 0.82829, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6820 - loss: 0.8934 - val_accuracy: 0.7061 - val_loss: 0.8283
# Epoch 24/500
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6923 - loss: 0.8684
# Epoch 24: val_loss improved from 0.82829 to 0.80186, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.6922 - loss: 0.8685 - val_accuracy: 0.7217 - val_loss: 0.8019
# Epoch 25/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7049 - loss: 0.8256
# Epoch 25: val_loss improved from 0.80186 to 0.78131, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7048 - loss: 0.8258 - val_accuracy: 0.7229 - val_loss: 0.7813
# Epoch 26/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7163 - loss: 0.7950
# Epoch 26: val_loss improved from 0.78131 to 0.72733, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7161 - loss: 0.7954 - val_accuracy: 0.7487 - val_loss: 0.7273
# Epoch 27/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7268 - loss: 0.7687
# Epoch 27: val_loss improved from 0.72733 to 0.71802, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7267 - loss: 0.7689 - val_accuracy: 0.7464 - val_loss: 0.7180
# Epoch 28/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7379 - loss: 0.7278
# Epoch 28: val_loss improved from 0.71802 to 0.67833, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7378 - loss: 0.7282 - val_accuracy: 0.7581 - val_loss: 0.6783
# Epoch 29/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7528 - loss: 0.6993
# Epoch 29: val_loss improved from 0.67833 to 0.67397, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7527 - loss: 0.6996 - val_accuracy: 0.7576 - val_loss: 0.6740
# Epoch 30/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7633 - loss: 0.6674
# Epoch 30: val_loss improved from 0.67397 to 0.65603, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7631 - loss: 0.6679 - val_accuracy: 0.7705 - val_loss: 0.6560
# Epoch 31/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7674 - loss: 0.6573
# Epoch 31: val_loss improved from 0.65603 to 0.60247, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7674 - loss: 0.6575 - val_accuracy: 0.7875 - val_loss: 0.6025
# Epoch 32/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7821 - loss: 0.6188
# Epoch 32: val_loss improved from 0.60247 to 0.58668, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.7819 - loss: 0.6193 - val_accuracy: 0.7942 - val_loss: 0.5867
# Epoch 33/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7894 - loss: 0.5944
# Epoch 33: val_loss improved from 0.58668 to 0.56056, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.7893 - loss: 0.5945 - val_accuracy: 0.7995 - val_loss: 0.5606
# Epoch 34/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8016 - loss: 0.5675
# Epoch 34: val_loss improved from 0.56056 to 0.52403, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8014 - loss: 0.5680 - val_accuracy: 0.8154 - val_loss: 0.5240
# Epoch 35/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8100 - loss: 0.5447
# Epoch 35: val_loss improved from 0.52403 to 0.50613, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8098 - loss: 0.5453 - val_accuracy: 0.8209 - val_loss: 0.5061
# Epoch 36/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8160 - loss: 0.5220
# Epoch 36: val_loss improved from 0.50613 to 0.49772, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8159 - loss: 0.5223 - val_accuracy: 0.8215 - val_loss: 0.4977
# Epoch 37/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8216 - loss: 0.5037
# Epoch 37: val_loss improved from 0.49772 to 0.47881, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8215 - loss: 0.5040 - val_accuracy: 0.8332 - val_loss: 0.4788
# Epoch 38/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8254 - loss: 0.4936
# Epoch 38: val_loss improved from 0.47881 to 0.47874, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8253 - loss: 0.4941 - val_accuracy: 0.8298 - val_loss: 0.4787
# Epoch 39/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8294 - loss: 0.4841
# Epoch 39: val_loss improved from 0.47874 to 0.47501, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8293 - loss: 0.4843 - val_accuracy: 0.8268 - val_loss: 0.4750
# Epoch 40/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8354 - loss: 0.4613
# Epoch 40: val_loss improved from 0.47501 to 0.41088, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8353 - loss: 0.4616 - val_accuracy: 0.8570 - val_loss: 0.4109
# Epoch 41/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8489 - loss: 0.4271
# Epoch 41: val_loss did not improve from 0.41088
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8487 - loss: 0.4278 - val_accuracy: 0.8544 - val_loss: 0.4155
# Epoch 42/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8478 - loss: 0.4275
# Epoch 42: val_loss did not improve from 0.41088
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8477 - loss: 0.4279 - val_accuracy: 0.8557 - val_loss: 0.4120
# Epoch 43/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8544 - loss: 0.4177
# Epoch 43: val_loss improved from 0.41088 to 0.37371, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8542 - loss: 0.4180 - val_accuracy: 0.8662 - val_loss: 0.3737
# Epoch 44/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8621 - loss: 0.3909
# Epoch 44: val_loss improved from 0.37371 to 0.37102, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8620 - loss: 0.3912 - val_accuracy: 0.8734 - val_loss: 0.3710
# Epoch 45/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8597 - loss: 0.3980
# Epoch 45: val_loss improved from 0.37102 to 0.36210, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8595 - loss: 0.3986 - val_accuracy: 0.8751 - val_loss: 0.3621
# Epoch 46/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8675 - loss: 0.3773
# Epoch 46: val_loss improved from 0.36210 to 0.36084, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8674 - loss: 0.3775 - val_accuracy: 0.8744 - val_loss: 0.3608
# Epoch 47/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8742 - loss: 0.3603
# Epoch 47: val_loss improved from 0.36084 to 0.34271, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8740 - loss: 0.3606 - val_accuracy: 0.8806 - val_loss: 0.3427
# Epoch 48/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8792 - loss: 0.3404
# Epoch 48: val_loss improved from 0.34271 to 0.31727, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8791 - loss: 0.3407 - val_accuracy: 0.8880 - val_loss: 0.3173
# Epoch 49/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8803 - loss: 0.3405
# Epoch 49: val_loss did not improve from 0.31727
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8802 - loss: 0.3406 - val_accuracy: 0.8813 - val_loss: 0.3378
# Epoch 50/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8853 - loss: 0.3244
# Epoch 50: val_loss did not improve from 0.31727
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8851 - loss: 0.3247 - val_accuracy: 0.8791 - val_loss: 0.3483
# Epoch 51/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8875 - loss: 0.3209
# Epoch 51: val_loss improved from 0.31727 to 0.30536, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8875 - loss: 0.3211 - val_accuracy: 0.8945 - val_loss: 0.3054
# Epoch 52/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8903 - loss: 0.3093
# Epoch 52: val_loss improved from 0.30536 to 0.30372, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8901 - loss: 0.3097 - val_accuracy: 0.8927 - val_loss: 0.3037
# Epoch 53/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8862 - loss: 0.3215
# Epoch 53: val_loss improved from 0.30372 to 0.28244, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8861 - loss: 0.3218 - val_accuracy: 0.9005 - val_loss: 0.2824
# Epoch 54/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8959 - loss: 0.2954
# Epoch 54: val_loss did not improve from 0.28244
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8958 - loss: 0.2957 - val_accuracy: 0.8878 - val_loss: 0.3224
# Epoch 55/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8873 - loss: 0.3264
# Epoch 55: val_loss improved from 0.28244 to 0.27380, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8873 - loss: 0.3263 - val_accuracy: 0.9031 - val_loss: 0.2738
# Epoch 56/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9106 - loss: 0.2563
# Epoch 56: val_loss improved from 0.27380 to 0.24188, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9105 - loss: 0.2563 - val_accuracy: 0.9165 - val_loss: 0.2419
# Epoch 57/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9110 - loss: 0.2497
# Epoch 57: val_loss did not improve from 0.24188
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9109 - loss: 0.2499 - val_accuracy: 0.9109 - val_loss: 0.2487
# Epoch 58/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9132 - loss: 0.2477
# Epoch 58: val_loss did not improve from 0.24188
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9130 - loss: 0.2482 - val_accuracy: 0.9051 - val_loss: 0.2622
# Epoch 59/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9083 - loss: 0.2580
# Epoch 59: val_loss improved from 0.24188 to 0.23974, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9083 - loss: 0.2582 - val_accuracy: 0.9144 - val_loss: 0.2397
# Epoch 60/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9092 - loss: 0.2619
# Epoch 60: val_loss did not improve from 0.23974
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9091 - loss: 0.2622 - val_accuracy: 0.8916 - val_loss: 0.3038
# Epoch 61/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9100 - loss: 0.2546
# Epoch 61: val_loss improved from 0.23974 to 0.20540, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9100 - loss: 0.2547 - val_accuracy: 0.9281 - val_loss: 0.2054
# Epoch 62/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9319 - loss: 0.1962
# Epoch 62: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9318 - loss: 0.1965 - val_accuracy: 0.9251 - val_loss: 0.2187
# Epoch 63/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9196 - loss: 0.2337
# Epoch 63: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9194 - loss: 0.2344 - val_accuracy: 0.9206 - val_loss: 0.2227
# Epoch 64/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9237 - loss: 0.2243
# Epoch 64: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9237 - loss: 0.2244 - val_accuracy: 0.9269 - val_loss: 0.2078
# Epoch 65/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9243 - loss: 0.2166
# Epoch 65: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9243 - loss: 0.2167 - val_accuracy: 0.9174 - val_loss: 0.2385
# Epoch 66/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9235 - loss: 0.2182
# Epoch 66: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9234 - loss: 0.2185 - val_accuracy: 0.9225 - val_loss: 0.2273
# Epoch 67/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9235 - loss: 0.2197
# Epoch 67: val_loss did not improve from 0.20540
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9233 - loss: 0.2203 - val_accuracy: 0.9245 - val_loss: 0.2236
# Epoch 68/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9208 - loss: 0.2306
# Epoch 68: val_loss improved from 0.20540 to 0.20202, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9207 - loss: 0.2307 - val_accuracy: 0.9306 - val_loss: 0.2020
# Epoch 69/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9287 - loss: 0.2022
# Epoch 69: val_loss improved from 0.20202 to 0.17284, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9287 - loss: 0.2022 - val_accuracy: 0.9437 - val_loss: 0.1728
# Epoch 70/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9376 - loss: 0.1819
# Epoch 70: val_loss did not improve from 0.17284
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9375 - loss: 0.1823 - val_accuracy: 0.9286 - val_loss: 0.2086
# Epoch 71/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9286 - loss: 0.2069
# Epoch 71: val_loss did not improve from 0.17284
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9285 - loss: 0.2071 - val_accuracy: 0.9328 - val_loss: 0.2002
# Epoch 72/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9324 - loss: 0.1939
# Epoch 72: val_loss did not improve from 0.17284
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9323 - loss: 0.1941 - val_accuracy: 0.9289 - val_loss: 0.2038
# Epoch 73/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9375 - loss: 0.1782
# Epoch 73: val_loss improved from 0.17284 to 0.17148, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9374 - loss: 0.1784 - val_accuracy: 0.9401 - val_loss: 0.1715
# Epoch 74/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9410 - loss: 0.1704
# Epoch 74: val_loss improved from 0.17148 to 0.15390, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9409 - loss: 0.1706 - val_accuracy: 0.9448 - val_loss: 0.1539
# Epoch 75/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9347 - loss: 0.1861
# Epoch 75: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9346 - loss: 0.1864 - val_accuracy: 0.9354 - val_loss: 0.1894
# Epoch 76/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9347 - loss: 0.1910
# Epoch 76: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9347 - loss: 0.1911 - val_accuracy: 0.9436 - val_loss: 0.1639
# Epoch 77/500
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9390 - loss: 0.1766
# Epoch 77: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9390 - loss: 0.1766 - val_accuracy: 0.9418 - val_loss: 0.1680
# Epoch 78/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9453 - loss: 0.1574
# Epoch 78: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9452 - loss: 0.1575 - val_accuracy: 0.9440 - val_loss: 0.1673
# Epoch 79/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9423 - loss: 0.1669
# Epoch 79: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9422 - loss: 0.1673 - val_accuracy: 0.9360 - val_loss: 0.1846
# Epoch 80/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9394 - loss: 0.1782
# Epoch 80: val_loss did not improve from 0.15390
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9393 - loss: 0.1785 - val_accuracy: 0.9406 - val_loss: 0.1703
# Epoch 81/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9390 - loss: 0.1761
# Epoch 81: val_loss improved from 0.15390 to 0.14674, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9390 - loss: 0.1762 - val_accuracy: 0.9484 - val_loss: 0.1467
# Epoch 82/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9483 - loss: 0.1481
# Epoch 82: val_loss improved from 0.14674 to 0.13595, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9482 - loss: 0.1483 - val_accuracy: 0.9530 - val_loss: 0.1360
# Epoch 83/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9530 - loss: 0.1361
# Epoch 83: val_loss did not improve from 0.13595
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9529 - loss: 0.1364 - val_accuracy: 0.9421 - val_loss: 0.1714
# Epoch 84/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9423 - loss: 0.1703
# Epoch 84: val_loss did not improve from 0.13595
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9422 - loss: 0.1705 - val_accuracy: 0.9445 - val_loss: 0.1617
# Epoch 85/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9439 - loss: 0.1623
# Epoch 85: val_loss did not improve from 0.13595
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9439 - loss: 0.1624 - val_accuracy: 0.9481 - val_loss: 0.1501
# Epoch 86/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9474 - loss: 0.1506
# Epoch 86: val_loss did not improve from 0.13595
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9474 - loss: 0.1508 - val_accuracy: 0.9459 - val_loss: 0.1529
# Epoch 87/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9474 - loss: 0.1527
# Epoch 87: val_loss improved from 0.13595 to 0.12695, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9473 - loss: 0.1529 - val_accuracy: 0.9553 - val_loss: 0.1270
# Epoch 88/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9499 - loss: 0.1459
# Epoch 88: val_loss did not improve from 0.12695
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9498 - loss: 0.1462 - val_accuracy: 0.9344 - val_loss: 0.2004
# Epoch 89/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9381 - loss: 0.2090
# Epoch 89: val_loss did not improve from 0.12695
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9380 - loss: 0.2087 - val_accuracy: 0.9490 - val_loss: 0.1551
# Epoch 90/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9520 - loss: 0.1390
# Epoch 90: val_loss did not improve from 0.12695
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9520 - loss: 0.1390 - val_accuracy: 0.9511 - val_loss: 0.1421
# Epoch 91/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9591 - loss: 0.1194
# Epoch 91: val_loss improved from 0.12695 to 0.12520, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9591 - loss: 0.1196 - val_accuracy: 0.9577 - val_loss: 0.1252
# Epoch 92/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9556 - loss: 0.1294
# Epoch 92: val_loss did not improve from 0.12520
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9555 - loss: 0.1296 - val_accuracy: 0.9395 - val_loss: 0.1812
# Epoch 93/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9401 - loss: 0.1756
# Epoch 93: val_loss did not improve from 0.12520
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9401 - loss: 0.1756 - val_accuracy: 0.9581 - val_loss: 0.1276
# Epoch 94/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9531 - loss: 0.1427
# Epoch 94: val_loss did not improve from 0.12520
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9530 - loss: 0.1429 - val_accuracy: 0.9566 - val_loss: 0.1326
# Epoch 95/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9509 - loss: 0.1389
# Epoch 95: val_loss improved from 0.12520 to 0.11662, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9508 - loss: 0.1390 - val_accuracy: 0.9606 - val_loss: 0.1166
# Epoch 96/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9577 - loss: 0.1238
# Epoch 96: val_loss did not improve from 0.11662
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9576 - loss: 0.1240 - val_accuracy: 0.9410 - val_loss: 0.1794
# Epoch 97/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9513 - loss: 0.1418
# Epoch 97: val_loss did not improve from 0.11662
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9513 - loss: 0.1418 - val_accuracy: 0.9579 - val_loss: 0.1252
# Epoch 98/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9532 - loss: 0.1419
# Epoch 98: val_loss did not improve from 0.11662
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9531 - loss: 0.1421 - val_accuracy: 0.9478 - val_loss: 0.1720
# Epoch 99/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9509 - loss: 0.1434
# Epoch 99: val_loss did not improve from 0.11662
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9509 - loss: 0.1434 - val_accuracy: 0.9616 - val_loss: 0.1193
# Epoch 100/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9610 - loss: 0.1140
# Epoch 100: val_loss improved from 0.11662 to 0.09853, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9610 - loss: 0.1141 - val_accuracy: 0.9673 - val_loss: 0.0985
# Epoch 101/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.1241
# Epoch 101: val_loss did not improve from 0.09853
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9585 - loss: 0.1246 - val_accuracy: 0.9599 - val_loss: 0.1157
# Epoch 102/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9559 - loss: 0.1350
# Epoch 102: val_loss did not improve from 0.09853
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9558 - loss: 0.1352 - val_accuracy: 0.9607 - val_loss: 0.1157
# Epoch 103/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.1293
# Epoch 103: val_loss improved from 0.09853 to 0.08808, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9571 - loss: 0.1294 - val_accuracy: 0.9700 - val_loss: 0.0881
# Epoch 104/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9621 - loss: 0.1142
# Epoch 104: val_loss did not improve from 0.08808
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9621 - loss: 0.1143 - val_accuracy: 0.9626 - val_loss: 0.1073
# Epoch 105/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9571 - loss: 0.1245
# Epoch 105: val_loss did not improve from 0.08808
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9570 - loss: 0.1247 - val_accuracy: 0.9493 - val_loss: 0.1524
# Epoch 106/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9531 - loss: 0.1436
# Epoch 106: val_loss did not improve from 0.08808
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9531 - loss: 0.1436 - val_accuracy: 0.9590 - val_loss: 0.1211
# Epoch 107/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9643 - loss: 0.1082
# Epoch 107: val_loss improved from 0.08808 to 0.08672, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9643 - loss: 0.1082 - val_accuracy: 0.9698 - val_loss: 0.0867
# Epoch 108/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9646 - loss: 0.1041
# Epoch 108: val_loss did not improve from 0.08672
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9646 - loss: 0.1041 - val_accuracy: 0.9605 - val_loss: 0.1227
# Epoch 109/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9568 - loss: 0.1301
# Epoch 109: val_loss did not improve from 0.08672
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9566 - loss: 0.1306 - val_accuracy: 0.9482 - val_loss: 0.1636
# Epoch 110/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9526 - loss: 0.1504
# Epoch 110: val_loss did not improve from 0.08672
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9525 - loss: 0.1506 - val_accuracy: 0.9553 - val_loss: 0.1303
# Epoch 111/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9595 - loss: 0.1233
# Epoch 111: val_loss improved from 0.08672 to 0.07959, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9595 - loss: 0.1233 - val_accuracy: 0.9738 - val_loss: 0.0796
# Epoch 112/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9642 - loss: 0.1086
# Epoch 112: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9642 - loss: 0.1087 - val_accuracy: 0.9752 - val_loss: 0.0820
# Epoch 113/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9728 - loss: 0.0810
# Epoch 113: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9728 - loss: 0.0811 - val_accuracy: 0.9644 - val_loss: 0.1096
# Epoch 114/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9640 - loss: 0.1112
# Epoch 114: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9639 - loss: 0.1114 - val_accuracy: 0.9625 - val_loss: 0.1164
# Epoch 115/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9623 - loss: 0.1192
# Epoch 115: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9622 - loss: 0.1194 - val_accuracy: 0.9612 - val_loss: 0.1268
# Epoch 116/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9605 - loss: 0.1231
# Epoch 116: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9605 - loss: 0.1231 - val_accuracy: 0.9750 - val_loss: 0.0799
# Epoch 117/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9645 - loss: 0.1084
# Epoch 117: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.9644 - loss: 0.1088 - val_accuracy: 0.9608 - val_loss: 0.1236
# Epoch 118/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9622 - loss: 0.1245
# Epoch 118: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9622 - loss: 0.1245 - val_accuracy: 0.9692 - val_loss: 0.1030
# Epoch 119/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9619 - loss: 0.1132
# Epoch 119: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9619 - loss: 0.1132 - val_accuracy: 0.9703 - val_loss: 0.0870
# Epoch 120/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9637 - loss: 0.1113
# Epoch 120: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9636 - loss: 0.1115 - val_accuracy: 0.9592 - val_loss: 0.1185
# Epoch 121/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9587 - loss: 0.1287
# Epoch 121: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9587 - loss: 0.1288 - val_accuracy: 0.9668 - val_loss: 0.1073
# Epoch 122/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9670 - loss: 0.0996
# Epoch 122: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9670 - loss: 0.0998 - val_accuracy: 0.9680 - val_loss: 0.0930
# Epoch 123/500
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9660 - loss: 0.1023
# Epoch 123: val_loss did not improve from 0.07959
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9660 - loss: 0.1023 - val_accuracy: 0.9661 - val_loss: 0.0944
# Epoch 124/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9719 - loss: 0.0845
# Epoch 124: val_loss improved from 0.07959 to 0.07725, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9719 - loss: 0.0845 - val_accuracy: 0.9739 - val_loss: 0.0772
# Epoch 125/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9631 - loss: 0.1154
# Epoch 125: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9630 - loss: 0.1156 - val_accuracy: 0.9596 - val_loss: 0.1361
# Epoch 126/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9599 - loss: 0.1245
# Epoch 126: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9599 - loss: 0.1245 - val_accuracy: 0.9675 - val_loss: 0.1022
# Epoch 127/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9682 - loss: 0.1007
# Epoch 127: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9681 - loss: 0.1010 - val_accuracy: 0.9641 - val_loss: 0.1002
# Epoch 128/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9658 - loss: 0.1047
# Epoch 128: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9658 - loss: 0.1047 - val_accuracy: 0.9671 - val_loss: 0.1010
# Epoch 129/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9688 - loss: 0.0929
# Epoch 129: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9687 - loss: 0.0932 - val_accuracy: 0.9699 - val_loss: 0.0912
# Epoch 130/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9619 - loss: 0.1208
# Epoch 130: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9618 - loss: 0.1210 - val_accuracy: 0.9620 - val_loss: 0.1143
# Epoch 131/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9662 - loss: 0.1089
# Epoch 131: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9662 - loss: 0.1089 - val_accuracy: 0.9708 - val_loss: 0.0998
# Epoch 132/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9721 - loss: 0.0848
# Epoch 132: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9721 - loss: 0.0848 - val_accuracy: 0.9726 - val_loss: 0.0827
# Epoch 133/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9734 - loss: 0.0827
# Epoch 133: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9732 - loss: 0.0839 - val_accuracy: 0.9486 - val_loss: 0.1703
# Epoch 134/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9593 - loss: 0.1235
# Epoch 134: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9593 - loss: 0.1234 - val_accuracy: 0.9723 - val_loss: 0.0909
# Epoch 135/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9696 - loss: 0.0966
# Epoch 135: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9695 - loss: 0.0969 - val_accuracy: 0.9645 - val_loss: 0.1101
# Epoch 136/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9677 - loss: 0.0991
# Epoch 136: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9677 - loss: 0.0991 - val_accuracy: 0.9782 - val_loss: 0.0793
# Epoch 137/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9703 - loss: 0.0926
# Epoch 137: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9703 - loss: 0.0926 - val_accuracy: 0.9699 - val_loss: 0.0935
# Epoch 138/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9708 - loss: 0.0913
# Epoch 138: val_loss did not improve from 0.07725
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9708 - loss: 0.0913 - val_accuracy: 0.9677 - val_loss: 0.1051
# Epoch 139/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9713 - loss: 0.0925
# ...
# Epoch 439/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 0.0611
# Epoch 439: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9866 - loss: 0.0610 - val_accuracy: 0.9882 - val_loss: 0.0508
# Epoch 440/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9857 - loss: 0.0652
# Epoch 440: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9857 - loss: 0.0654 - val_accuracy: 0.9876 - val_loss: 0.0564
# Epoch 441/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9865 - loss: 0.0674
# Epoch 441: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9865 - loss: 0.0674 - val_accuracy: 0.9901 - val_loss: 0.0469
# Epoch 442/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9870 - loss: 0.0632
# Epoch 442: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9870 - loss: 0.0632 - val_accuracy: 0.9897 - val_loss: 0.0507
# Epoch 443/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0580
# Epoch 443: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9875 - loss: 0.0580 - val_accuracy: 0.9908 - val_loss: 0.0424
# Epoch 444/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.0639
# Epoch 444: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9874 - loss: 0.0639 - val_accuracy: 0.9932 - val_loss: 0.0357
# Epoch 445/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9909 - loss: 0.0396
# Epoch 445: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9909 - loss: 0.0397 - val_accuracy: 0.9873 - val_loss: 0.0562
# Epoch 446/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9886 - loss: 0.0502
# Epoch 446: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9886 - loss: 0.0502 - val_accuracy: 0.9868 - val_loss: 0.0583
# Epoch 447/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0475
# Epoch 447: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9892 - loss: 0.0476 - val_accuracy: 0.9871 - val_loss: 0.0579
# Epoch 448/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9878 - loss: 0.0569
# Epoch 448: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9878 - loss: 0.0571 - val_accuracy: 0.9829 - val_loss: 0.0731
# Epoch 449/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9854 - loss: 0.0700
# Epoch 449: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9854 - loss: 0.0700 - val_accuracy: 0.9822 - val_loss: 0.0911
# Epoch 450/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0611
# Epoch 450: val_loss did not improve from 0.02761
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9875 - loss: 0.0612 - val_accuracy: 0.9885 - val_loss: 0.0523
# Epoch 451/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0517
# Epoch 451: val_loss improved from 0.02761 to 0.02728, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9880 - loss: 0.0518 - val_accuracy: 0.9924 - val_loss: 0.0273
# Epoch 452/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9901 - loss: 0.0474
# Epoch 452: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9900 - loss: 0.0475 - val_accuracy: 0.9879 - val_loss: 0.0593
# Epoch 453/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9894 - loss: 0.0454
# Epoch 453: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9894 - loss: 0.0454 - val_accuracy: 0.9925 - val_loss: 0.0318
# Epoch 454/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0468
# Epoch 454: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9892 - loss: 0.0469 - val_accuracy: 0.9884 - val_loss: 0.0476
# Epoch 455/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9881 - loss: 0.0595
# Epoch 455: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9881 - loss: 0.0597 - val_accuracy: 0.9837 - val_loss: 0.0807
# Epoch 456/500
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9853 - loss: 0.0740
# Epoch 456: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9853 - loss: 0.0741 - val_accuracy: 0.9904 - val_loss: 0.0503
# Epoch 457/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0497
# Epoch 457: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9892 - loss: 0.0497 - val_accuracy: 0.9863 - val_loss: 0.0561
# Epoch 458/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9883 - loss: 0.0550
# Epoch 458: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9883 - loss: 0.0550 - val_accuracy: 0.9850 - val_loss: 0.0665
# Epoch 459/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9884 - loss: 0.0519
# Epoch 459: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9884 - loss: 0.0519 - val_accuracy: 0.9844 - val_loss: 0.0797
# Epoch 460/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9867 - loss: 0.0625
# Epoch 460: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9867 - loss: 0.0625 - val_accuracy: 0.9904 - val_loss: 0.0388
# Epoch 461/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.0421
# Epoch 461: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9902 - loss: 0.0422 - val_accuracy: 0.9877 - val_loss: 0.0568
# Epoch 462/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9875 - loss: 0.0606
# Epoch 462: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9875 - loss: 0.0607 - val_accuracy: 0.9901 - val_loss: 0.0404
# Epoch 463/500
# 466/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0571
# Epoch 463: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9878 - loss: 0.0572 - val_accuracy: 0.9869 - val_loss: 0.0640
# Epoch 464/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9892 - loss: 0.0497
# Epoch 464: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9892 - loss: 0.0498 - val_accuracy: 0.9919 - val_loss: 0.0442
# Epoch 465/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9870 - loss: 0.0647
# Epoch 465: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9870 - loss: 0.0648 - val_accuracy: 0.9890 - val_loss: 0.0580
# Epoch 466/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9881 - loss: 0.0556
# Epoch 466: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9881 - loss: 0.0558 - val_accuracy: 0.9895 - val_loss: 0.0421
# Epoch 467/500
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9895 - loss: 0.0460
# Epoch 467: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9895 - loss: 0.0460 - val_accuracy: 0.9902 - val_loss: 0.0452
# Epoch 468/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9904 - loss: 0.0441
# Epoch 468: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9904 - loss: 0.0443 - val_accuracy: 0.9834 - val_loss: 0.0757
# Epoch 469/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9873 - loss: 0.0565
# Epoch 469: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9873 - loss: 0.0565 - val_accuracy: 0.9887 - val_loss: 0.0562
# Epoch 470/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0492
# Epoch 470: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9880 - loss: 0.0491 - val_accuracy: 0.9922 - val_loss: 0.0306
# Epoch 471/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9915 - loss: 0.0360
# Epoch 471: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9915 - loss: 0.0362 - val_accuracy: 0.9879 - val_loss: 0.0539
# Epoch 472/500
# 464/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9880 - loss: 0.0535
# Epoch 472: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9880 - loss: 0.0536 - val_accuracy: 0.9878 - val_loss: 0.0591
# Epoch 473/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9866 - loss: 0.0647
# Epoch 473: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9866 - loss: 0.0649 - val_accuracy: 0.9861 - val_loss: 0.0694
# Epoch 474/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9882 - loss: 0.0566
# Epoch 474: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9882 - loss: 0.0566 - val_accuracy: 0.9909 - val_loss: 0.0477
# Epoch 475/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9911 - loss: 0.0371
# Epoch 475: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9910 - loss: 0.0372 - val_accuracy: 0.9892 - val_loss: 0.0500
# Epoch 476/500
# 459/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9852 - loss: 0.0737
# Epoch 476: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9851 - loss: 0.0742 - val_accuracy: 0.9773 - val_loss: 0.1231
# Epoch 477/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9834 - loss: 0.0820
# Epoch 477: val_loss did not improve from 0.02728
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9834 - loss: 0.0819 - val_accuracy: 0.9900 - val_loss: 0.0365
# Epoch 478/500
# 468/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0365
# Epoch 478: val_loss improved from 0.02728 to 0.02058, saving model to best_model.keras
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9918 - loss: 0.0365 - val_accuracy: 0.9945 - val_loss: 0.0206
# Epoch 479/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9934 - loss: 0.0324
# Epoch 479: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9934 - loss: 0.0325 - val_accuracy: 0.9862 - val_loss: 0.0652
# Epoch 480/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0484
# Epoch 480: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9893 - loss: 0.0486 - val_accuracy: 0.9885 - val_loss: 0.0530
# Epoch 481/500
# 465/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9876 - loss: 0.0529
# Epoch 481: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9876 - loss: 0.0530 - val_accuracy: 0.9889 - val_loss: 0.0521
# Epoch 482/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 0.0510
# Epoch 482: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9889 - loss: 0.0512 - val_accuracy: 0.9854 - val_loss: 0.0695
# Epoch 483/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9833 - loss: 0.0947
# Epoch 483: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9833 - loss: 0.0947 - val_accuracy: 0.9911 - val_loss: 0.0413
# Epoch 484/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9879 - loss: 0.0572
# Epoch 484: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9879 - loss: 0.0572 - val_accuracy: 0.9873 - val_loss: 0.0633
# Epoch 485/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9910 - loss: 0.0397
# Epoch 485: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9909 - loss: 0.0398 - val_accuracy: 0.9918 - val_loss: 0.0340
# Epoch 486/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0559
# Epoch 486: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9884 - loss: 0.0560 - val_accuracy: 0.9855 - val_loss: 0.0714
# Epoch 487/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9876 - loss: 0.0625
# Epoch 487: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9876 - loss: 0.0624 - val_accuracy: 0.9907 - val_loss: 0.0392
# Epoch 488/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9889 - loss: 0.0545
# Epoch 488: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9889 - loss: 0.0544 - val_accuracy: 0.9927 - val_loss: 0.0291
# Epoch 489/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9902 - loss: 0.0453
# Epoch 489: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9901 - loss: 0.0454 - val_accuracy: 0.9899 - val_loss: 0.0387
# Epoch 490/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9900 - loss: 0.0544
# Epoch 490: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9899 - loss: 0.0545 - val_accuracy: 0.9901 - val_loss: 0.0452
# Epoch 491/500
# 463/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9874 - loss: 0.0620
# Epoch 491: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9874 - loss: 0.0621 - val_accuracy: 0.9895 - val_loss: 0.0477
# Epoch 492/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9888 - loss: 0.0609
# Epoch 492: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9888 - loss: 0.0611 - val_accuracy: 0.9876 - val_loss: 0.0606
# Epoch 493/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9854 - loss: 0.0757
# Epoch 493: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9854 - loss: 0.0757 - val_accuracy: 0.9935 - val_loss: 0.0331
# Epoch 494/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9918 - loss: 0.0349
# Epoch 494: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9917 - loss: 0.0351 - val_accuracy: 0.9887 - val_loss: 0.0456
# Epoch 495/500
# 467/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9911 - loss: 0.0417
# Epoch 495: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9911 - loss: 0.0417 - val_accuracy: 0.9887 - val_loss: 0.0506
# Epoch 496/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9872 - loss: 0.0593
# Epoch 496: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9872 - loss: 0.0594 - val_accuracy: 0.9848 - val_loss: 0.0825
# Epoch 497/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9869 - loss: 0.0631
# Epoch 497: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9869 - loss: 0.0631 - val_accuracy: 0.9894 - val_loss: 0.0464
# Epoch 498/500
# 462/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9893 - loss: 0.0588
# Epoch 498: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9893 - loss: 0.0589 - val_accuracy: 0.9885 - val_loss: 0.0564
# Epoch 499/500
# 460/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9885 - loss: 0.0611
# Epoch 499: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9884 - loss: 0.0614 - val_accuracy: 0.9864 - val_loss: 0.0724
# Epoch 500/500
# 461/469 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9860 - loss: 0.0644
# Epoch 500: val_loss did not improve from 0.02058
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9861 - loss: 0.0644 - val_accuracy: 0.9907 - val_loss: 0.0417

# %%
# lets save our model
model.save("color_model.keras")

# %% [markdown]
# ## When to use a Sequential model
#
# A `Sequential` model is appropriate for **a plain stack of layers**
# where each layer has **exactly one input tensor and one output tensor**.
#
# Schematically, the following `Sequential` model:

# %%
# Define Sequential model with 3 layers
model = keras.Sequential(
    [
        layers.Dense(2, activation="relu", name="layer1"),
        layers.Dense(3, activation="relu", name="layer2"),
        layers.Dense(4, name="layer3"),
    ]
)
# Call model on a test input
x = ops.ones((3, 3))
y = model(x)

# %% [markdown]
# is equivalent to this function:

# %%
# Create 3 layers
layer1 = layers.Dense(2, activation="relu", name="layer1")
layer2 = layers.Dense(3, activation="relu", name="layer2")
layer3 = layers.Dense(4, name="layer3")

# Call layers on a test input
x = ops.ones((3, 3))
y = layer3(layer2(layer1(x)))

# %% [markdown]
# A Sequential model is **not appropriate** when:
#
# - Your model has multiple inputs or multiple outputs
# - Any of your layers has multiple inputs or multiple outputs
# - You need to do layer sharing
# - You want non-linear topology (e.g. a residual connection, a multi-branch
# model)

# %% [markdown]
# ## Creating a Sequential model
#
# You can create a Sequential model by passing a list of layers to the Sequential
# constructor:

# %%
model = keras.Sequential(
    [
        layers.Dense(2, activation="relu"),
        layers.Dense(3, activation="relu"),
        layers.Dense(4),
    ]
)

# %% [markdown]
# Its layers are accessible via the `layers` attribute:

# %%
model.layers
# Out:
# [<Dense name=dense, built=False>,
#  <Dense name=dense_1, built=False>,
#  <Dense name=dense_2, built=False>]

# %% [markdown]
# You can also create a Sequential model incrementally via the `add()` method:

# %%
model = keras.Sequential()
model.add(layers.Dense(2, activation="relu"))
model.add(layers.Dense(3, activation="relu"))
model.add(layers.Dense(4))

# %% [markdown]
# Note that there's also a corresponding `pop()` method to remove layers:
# a Sequential model behaves very much like a list of layers.

# %%
model.pop()
print(len(model.layers))  # 2
# Out:
# 2

# %% [markdown]
# Also note that the Sequential constructor accepts a `name` argument, just like
# any layer or model in Keras. This is useful to annotate TensorBoard graphs
# with semantically meaningful names.

# %%
model = keras.Sequential(name="my_sequential")
model.add(layers.Dense(2, activation="relu", name="layer1"))
model.add(layers.Dense(3, activation="relu", name="layer2"))
model.add(layers.Dense(4, name="layer3"))

# %% [markdown]
# ## Specifying the input shape in advance
#
# Generally, all layers in Keras need to know the shape of their inputs
# in order to be able to create their weights. So when you create a layer like
# this, initially, it has no weights:

# %%
layer = layers.Dense(3)
layer.weights  # Empty
# Out:
# []

# %% [markdown]
# It creates its weights the first time it is called on an input, since the shape
# of the weights depends on the shape of the inputs:

# %%
# Call layer on a test input
x = ops.ones((1, 4))
y = layer(x)
layer.weights  # Now it has weights, of shape (4, 3) and (3,)
# Out:
# [<KerasVariable shape=(4, 3), dtype=float32, path=dense_6/kernel>,
#  <KerasVariable shape=(3,), dtype=float32, path=dense_6/bias>]

# %% [markdown]
# Naturally, this also applies to Sequential models. When you instantiate a
# Sequential model without an input shape, it isn't "built": it has no weights
# (and calling
# `model.weights` results in an error stating just this). The weights are created
# when the model first sees some input data:

# %%
model = keras.Sequential(
    [
        layers.Dense(2, activation="relu"),
        layers.Dense(3, activation="relu"),
        layers.Dense(4),
    ]
)  # No weights at this stage!

# At this point, you can't do this:
# model.weights

# You also can't do this:
# model.summary()

# Call the model on a test input
x = ops.ones((1, 4))
y = model(x)
print("Number of weights after calling the model:", len(model.weights))  # 6
# Out:
# Number of weights after calling the model: 6

# %% [markdown]
# Once a model is "built", you can call its `summary()` method to display its
# contents:

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                      │ (1, 2)                      │              10 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (1, 3)                      │               9 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (1, 4)                      │              16 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 35 (140.00 B)
#  Trainable params: 35 (140.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# However, it can be very useful when building a Sequential model incrementally
# to be able to display the summary of the model so far, including the current
# output shape. In this case, you should start your model by passing an `Input`
# object to your model, so that it knows its input shape from the start:

# %%
model = keras.Sequential()
model.add(keras.Input(shape=(4,)))
model.add(layers.Dense(2, activation="relu"))

model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                     │ (None, 2)                   │              10 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10 (40.00 B)
#  Trainable params: 10 (40.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Note that the `Input` object is not displayed as part of `model.layers`, since
# it isn't a layer:

# %%
model.layers
# Out:
# [<Dense name=dense_11, built=True>]

# %% [markdown]
# Models built with a predefined input shape like this always have weights (even
# before seeing any data) and always have a defined output shape.
#
# In general, it's a recommended best practice to always specify the input shape
# of a Sequential model in advance if you know what it is.

# %% [markdown]
# ## A common debugging workflow: `add()` + `summary()`
#
# When building a new Sequential architecture, it's useful to incrementally stack
# layers with `add()` and frequently print model summaries. For instance, this
# enables you to monitor how a stack of `Conv2D` and `MaxPooling2D` layers is
# downsampling image feature maps:

# %%
train_images = None
train_captions = None
test_images = None
test_captions = None
train_image_rg = None
train_image_rb = None
train_image_gb = None
train_image_ra = None
train_image_ga = None
train_image_ba = None
train_image_rba = None
train_image_rga = None
train_image_bga = None
classes = [
  "airplane", #0
  "automobile", #1
  "bird", #2
  "cat", #3
  "deer", #4
  "dog", #5
  "frog", #6
  "horse", #7
  "ship", #8
  "truck", #9
  ]

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.utils import to_categorical

def prepare_dataset(image_width, image_height, num_classes=10):
    # Load CIFAR-10 dataset
    (train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar10.load_data()

    # Normalize pixel values to [0, 1]
    train_images = train_images.astype('float32') / 255.0
    test_images = test_images.astype('float32') / 255.0

    # Resize images to (image_width, image_height)
    train_resized = tf.image.resize(train_images, [image_width, image_height]).numpy()
    test_resized = tf.image.resize(test_images, [image_width, image_height]).numpy()

    # Add Alpha channel (set to 1.0 for full opacity)
    def add_alpha_channel(images):
        alpha_channel = np.ones((images.shape[0], image_width, image_height, 1), dtype=np.float32)
        return np.concatenate([images, alpha_channel], axis=-1)

    train_rgba = add_alpha_channel(train_resized)
    test_rgba = add_alpha_channel(test_resized)

    # Create color combination inputs
    # Pair Inputs: (2 channels)
    train_rg = train_rgba[..., [0, 1]]  # Red + Green
    test_rg = test_rgba[..., [0, 1]]

    train_rb = train_rgba[..., [0, 2]]  # Red + Blue
    test_rb = test_rgba[..., [0, 2]]

    train_gb = train_rgba[..., [1, 2]]  # Green + Blue
    test_gb = test_rgba[..., [1, 2]]

    train_ra = train_rgba[..., [0, 3]]  # Red + Alpha
    test_ra = test_rgba[..., [0, 3]]

    train_ga = train_rgba[..., [1, 3]]  # Green + Alpha
    test_ga = test_rgba[..., [1, 3]]

    train_ba = train_rgba[..., [2, 3]]  # Blue + Alpha
    test_ba = test_rgba[..., [2, 3]]

    # Triplet Inputs: (3 channels)
    train_rba = train_rgba[..., [0, 2, 3]]  # Red + Blue + Alpha
    test_rba = test_rgba[..., [0, 2, 3]]

    train_rga = train_rgba[..., [0, 1, 3]]  # Red + Green + Alpha
    test_rga = test_rgba[..., [0, 1, 3]]

    train_bga = train_rgba[..., [2, 1, 3]]  # Blue + Green + Alpha
    test_bga = test_rgba[..., [2, 1, 3]]

    # One-hot encode labels
    train_labels = to_categorical(train_labels, num_classes)
    test_labels = to_categorical(test_labels, num_classes)

    # Organize inputs into dictionaries
    train_inputs = {
        "rgba_input": train_rgba,
        "rg_input": train_rg,
        "rb_input": train_rb,
        "gb_input": train_gb,
        "ra_input": train_ra,
        "ga_input": train_ga,
        "ba_input": train_ba,
        "rba_input": train_rba,
        "rga_input": train_rga,
        "bga_input": train_bga
    }

    test_inputs = {
        "rgba_input": test_rgba,
        "rg_input": test_rg,
        "rb_input": test_rb,
        "gb_input": test_gb,
        "ra_input": test_ra,
        "ga_input": test_ga,
        "ba_input": test_ba,
        "rba_input": test_rba,
        "rga_input": test_rga,
        "bga_input": test_bga
    }

    return train_inputs, train_labels, test_inputs, test_labels

# %%
def verify_data_shapes(train_inputs, test_inputs):
    print("Training Inputs Shapes:")
    for key, value in train_inputs.items():
        print(f"{key}: {value.shape}")

    print("\nTesting Inputs Shapes:")
    for key, value in test_inputs.items():
        print(f"{key}: {value.shape}")

# %%
def create_parent_model(image_width, image_height, num_classes=10):
    rgba_input = keras.Input(shape=(image_width, image_height, 4), name="rgba_input")

    rg_input = keras.Input(shape=(image_width, image_height, 2), name="rg_input")
    rb_input = keras.Input(shape=(image_width, image_height, 2), name="rb_input")
    gb_input = keras.Input(shape=(image_width, image_height, 2), name="gb_input")

    ra_input = keras.Input(shape=(image_width, image_height, 2), name="ra_input")
    ga_input = keras.Input(shape=(image_width, image_height, 2), name="ga_input")
    ba_input = keras.Input(shape=(image_width, image_height, 2), name="ba_input")

    rga_input = keras.Input(shape=(image_width, image_height, 3), name="rga_input")
    bga_input = keras.Input(shape=(image_width, image_height, 3), name="bga_input")
    rba_input = keras.Input(shape=(image_width, image_height, 3), name="rba_input")
    # Flatten all inputs before passing to Dense layers
    rgba_flat = layers.Flatten()(rgba_input)
    rg_flat = layers.Flatten()(rg_input)
    rb_flat = layers.Flatten()(rb_input)
    gb_flat = layers.Flatten()(gb_input)
    ra_flat = layers.Flatten()(ra_input)
    ga_flat = layers.Flatten()(ga_input)
    ba_flat = layers.Flatten()(ba_input)
    rga_flat = layers.Flatten()(rga_input)
    bga_flat = layers.Flatten()(bga_input)
    rba_flat = layers.Flatten()(rba_input)

    # rgba

    rgba = layers.Dense(1024, activation="relu", name="rgba_dense_1")(rgba_flat)
    rgba = layers.Dense(1024, activation="relu", name="rgba_dense_2")(rgba)

    # red + green
    rg = layers.Dense(1024, activation="relu", name="rg_dense_1")(rg_flat)
    rg = layers.Dense(1024, activation="relu", name="rg_dense_2")(rg)
    # green + blue
    gb = layers.Dense(1024, activation="relu", name="gb_dense_1")(gb_flat)
    gb = layers.Dense(1024, activation="relu", name="gb_dense_2")(gb)
    # red + blue
    rb = layers.Dense(1024, activation="relu", name="rb_dense_1")(rb_flat)
    rb = layers.Dense(1024, activation="relu", name="rb_dense_2")(rb)
    # red + alpha
    ra = layers.Dense(1024, activation="relu", name="ra_dense_1")(ra_flat)
    ra = layers.Dense(1024, activation="relu", name="ra_dense_2")(ra)
    # green + alpha
    ga = layers.Dense(1024, activation="relu", name="ga_dense_1")(ga_flat)
    ga = layers.Dense(1024, activation="relu", name="ga_dense_2")(ga)
    # blue + alpha
    ba = layers.Dense(1024, activation="relu", name="ba_dense_1")(ba_flat)
    ba = layers.Dense(1024, activation="relu", name="ba_dense_2")(ba)
    # red + green + alpha
    rga = layers.Dense(1024, activation="relu", name="rga_dense_1")(rga_flat)
    rga = layers.Dense(1024, activation="relu", name="rga_dense_2")(rga)
    # blue + green + alpha
    bga = layers.Dense(1024, activation="relu", name="bga_dense_1")(bga_flat)
    bga = layers.Dense(1024, activation="relu", name="bga_dense_2")(bga)
    # red + blue + alpha
    rba = layers.Dense(1024, activation="relu", name="rba_dense_1")(rba_flat)
    rba = layers.Dense(1024, activation="relu", name="rba_dense_2")(rba)

    # Concatenate all processed inputs
    color_layers = layers.concatenate([rgba, rg, gb, rb, ra, ga, ba, rga, bga, rba], name="color_concatenation")
    #color_layers = layers.concatenate([rgba, rg, gb, rb, ra, ga, ba], name="color_concatenation")
    color_layers = layers.Flatten()(color_layers)

    # Further Dense layers
    dense_color_1 = layers.Dense(1024, activation="relu", name="dense_color_1")(color_layers)
    dense_color_2 = layers.Dense(512, activation="relu", name="dense_color_2")(dense_color_1)
    dense_color_3 = layers.Dense(256, activation="relu", name="dense_color_3")(dense_color_2)
    dense_color_4 = layers.Dense(128, activation="relu", name="dense_color_4")(dense_color_3)
    dense_color_5 = layers.Dense(64, activation="relu", name="dense_color_5")(dense_color_4)
    dense_color_6 = layers.Dense(32, activation="relu", name="dense_color_6")(dense_color_5)

    # Output layer
    output = layers.Dense(num_classes, activation='softmax', name="output")(dense_color_6)

    # Define the model
    model = keras.Model(
        inputs=[
            rgba_input,
            rg_input, rb_input, gb_input, ra_input,
            ga_input, ba_input,
            rba_input, rga_input, bga_input
        ],
        outputs=[dense_color_6],
        name="color_model"
    )
    model.name = "color_model"
    return model

out_model = create_parent_model(32, 32, 10)
out_model.summary()
# Out:
# Model: "color_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ rgba_input (InputLayer)   │ (None, 32, 32, 4)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 4096)           │              0 │ rgba_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 2048)           │              0 │ rg_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_3 (Flatten)       │ (None, 2048)           │              0 │ gb_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_2 (Flatten)       │ (None, 2048)           │              0 │ rb_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_4 (Flatten)       │ (None, 2048)           │              0 │ ra_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_5 (Flatten)       │ (None, 2048)           │              0 │ ga_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_6 (Flatten)       │ (None, 2048)           │              0 │ ba_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_dense_1 (Dense)      │ (None, 1024)           │      4,195,328 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_3[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_2[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_dense_2 (Dense)      │ (None, 1024)           │      1,049,600 │ rgba_dense_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ rg_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ gb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ rb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ra_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ga_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ba_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ color_concatenation       │ (None, 7168)           │              0 │ rgba_dense_2[0][0],    │
# │ (Concatenate)             │                        │                │ rg_dense_2[0][0],      │
# │                           │                        │                │ gb_dense_2[0][0],      │
# │                           │                        │                │ rb_dense_2[0][0],      │
# │                           │                        │                │ ra_dense_2[0][0],      │
# │                           │                        │                │ ga_dense_2[0][0],      │
# │                           │                        │                │ ba_dense_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_10 (Flatten)      │ (None, 7168)           │              0 │ color_concatenation[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_1 (Dense)     │ (None, 1024)           │      7,341,056 │ flatten_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_2 (Dense)     │ (None, 512)            │        524,800 │ dense_color_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_3 (Dense)     │ (None, 256)            │        131,328 │ dense_color_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_4 (Dense)     │ (None, 128)            │         32,896 │ dense_color_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_5 (Dense)     │ (None, 64)             │          8,256 │ dense_color_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_6 (Dense)     │ (None, 32)             │          2,080 │ dense_color_5[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 32,172,000 (122.73 MB)
#  Trainable params: 32,172,000 (122.73 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.utils import Sequence, to_categorical

class CIFAR10DataGenerator(Sequence):
    def __init__(self, images, labels, image_width, image_height, batch_size=32, num_classes=10, shuffle=True):
        self.images = images
        self.labels = labels
        self.image_width = image_width
        self.image_height = image_height
        self.batch_size = batch_size
        self.num_classes = num_classes
        self.shuffle = shuffle
        self.indices = np.arange(len(self.images))
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        batch_indices = self.indices[index * self.batch_size:(index + 1) * self.batch_size]
        batch_images = self.images[batch_indices]
        batch_labels = self.labels[batch_indices]

        # Preprocess the batch
        inputs = self.preprocess_batch(batch_images)

        # One-hot encode labels
        batch_labels = to_categorical(batch_labels, num_classes=self.num_classes)

        return inputs, batch_labels

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indices)

    def preprocess_batch(self, batch_images):
        # Normalize pixel values to [0, 1]
        batch_images = batch_images.astype('float32') / 255.0

        # Resize images to (32, 32) if not already
        resized = tf.image.resize(batch_images, [self.image_width, self.image_height]).numpy()

        # Add Alpha channel (set to 1.0 for full opacity)
        alpha_channel = np.ones((resized.shape[0], self.image_width, self.image_height, 1), dtype=np.float32)
        rgba = np.concatenate([resized, alpha_channel], axis=-1)  # Shape: (batch_size, 32, 32, 4)

        # Create pair inputs (2 channels)
        rg = rgba[..., [0, 1]]  # Red + Green
        rb = rgba[..., [0, 2]]  # Red + Blue
        gb = rgba[..., [1, 2]]  # Green + Blue
        ra = rgba[..., [0, 3]]  # Red + Alpha
        ga = rgba[..., [1, 3]]  # Green + Alpha
        ba = rgba[..., [2, 3]]  # Blue + Alpha

        # Create triplet inputs (3 channels)
        rba = rgba[..., [0, 2, 3]]  # Red + Blue + Alpha
        rga = rgba[..., [0, 1, 3]]  # Red + Green + Alpha
        bga = rgba[..., [2, 1, 3]]  # Blue + Green + Alpha

        # Organize inputs into a dictionary
        inputs = {
            "rgba_input": rgba,
            "rg_input": rg,
            "rb_input": rb,
            "gb_input": gb,
            "ra_input": ra,
            "ga_input": ga,
            "ba_input": ba,
            "rba_input": rba,
            "rga_input": rga,
            "bga_input": bga
        }

        # Verification: Print shapes (optional, remove after verification)
        # print("Batch Shapes:")
        # for key, value in inputs.items():
        #     print(f"{key}: {value.shape}")

        return inputs

# %%
import datetime

# Define summary writers
current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
train_log_dir = f'logs_custom/train/{current_time}'
val_log_dir = f'logs_custom/val/{current_time}'
train_summary_writer = tf.summary.create_file_writer(train_log_dir)
val_summary_writer = tf.summary.create_file_writer(val_log_dir)

for epoch in range(epochs):
    # Reset metrics
    train_loss.reset_states()
    train_accuracy.reset_states()
    val_loss.reset_states()
    val_accuracy.reset_states()

    # Training
    for batch, (inputs, labels) in enumerate(train_generator):
        train_step(inputs, labels)

        # Optional: Print progress every 100 batches
        if batch % 100 == 0:
            print(f"Epoch {epoch+1}, Batch {batch}, Loss: {train_loss.result():.4f}, Accuracy: {train_accuracy.result():.4f}")

    # Validation
    for val_inputs, val_labels in validation_generator:
        val_step(val_inputs, val_labels)

    # Log metrics to TensorBoard
    with train_summary_writer.as_default():
        tf.summary.scalar('loss', train_loss.result(), step=epoch)
        tf.summary.scalar('accuracy', train_accuracy.result(), step=epoch)

    with val_summary_writer.as_default():
        tf.summary.scalar('loss', val_loss.result(), step=epoch)
        tf.summary.scalar('accuracy', val_accuracy.result(), step=epoch)

    # Print epoch metrics
    template = (
        "Epoch {}/{}\n"
        "Train Loss: {:.4f}, Train Accuracy: {:.4f}\n"
        "Val Loss: {:.4f}, Val Accuracy: {:.4f}"
    )
    print(template.format(
        epoch + 1,
        epochs,
        train_loss.result(),
        train_accuracy.result(),
        val_loss.result(),
        val_accuracy.result()
    ))

    # Early Stopping and Checkpointing
    if val_loss.result() < best_val_loss:
        best_val_loss = val_loss.result()
        wait = 0
        # Save the best model
        model.save('best_color_model.h5')
        print("Model checkpoint saved.")
    else:
        wait += 1
        if wait >= patience:
            print("Early stopping triggered.")
            break
# Out:
# Training Inputs Shapes:
# rgba_input: (50000, 32, 32, 4)
# rg_input: (50000, 32, 32, 2)
# rb_input: (50000, 32, 32, 2)
# gb_input: (50000, 32, 32, 2)
# ra_input: (50000, 32, 32, 2)
# ga_input: (50000, 32, 32, 2)
# ba_input: (50000, 32, 32, 2)
# rba_input: (50000, 32, 32, 3)
# rga_input: (50000, 32, 32, 3)
# bga_input: (50000, 32, 32, 3)
#
# Testing Inputs Shapes:
# rgba_input: (10000, 32, 32, 4)
# rg_input: (10000, 32, 32, 2)
# rb_input: (10000, 32, 32, 2)
# gb_input: (10000, 32, 32, 2)
# ra_input: (10000, 32, 32, 2)
# ga_input: (10000, 32, 32, 2)
# ba_input: (10000, 32, 32, 2)
# rba_input: (10000, 32, 32, 3)
# rga_input: (10000, 32, 32, 3)
# bga_input: (10000, 32, 32, 3)
# Model: "color_model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ rgba_input (InputLayer)   │ (None, 32, 32, 4)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_input (InputLayer)     │ (None, 32, 32, 2)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_11 (Flatten)      │ (None, 4096)           │              0 │ rgba_input[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_12 (Flatten)      │ (None, 2048)           │              0 │ rg_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_14 (Flatten)      │ (None, 2048)           │              0 │ gb_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_13 (Flatten)      │ (None, 2048)           │              0 │ rb_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_15 (Flatten)      │ (None, 2048)           │              0 │ ra_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_16 (Flatten)      │ (None, 2048)           │              0 │ ga_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_17 (Flatten)      │ (None, 2048)           │              0 │ ba_input[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_dense_1 (Dense)      │ (None, 1024)           │      4,195,328 │ flatten_11[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_12[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_14[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_13[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_15[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_16[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_1 (Dense)        │ (None, 1024)           │      2,098,176 │ flatten_17[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rgba_dense_2 (Dense)      │ (None, 1024)           │      1,049,600 │ rgba_dense_1[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rg_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ rg_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ gb_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ gb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rb_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ rb_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ra_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ra_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ga_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ga_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ ba_dense_2 (Dense)        │ (None, 1024)           │      1,049,600 │ ba_dense_1[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ color_concatenation       │ (None, 7168)           │              0 │ rgba_dense_2[0][0],    │
# │ (Concatenate)             │                        │                │ rg_dense_2[0][0],      │
# │                           │                        │                │ gb_dense_2[0][0],      │
# │                           │                        │                │ rb_dense_2[0][0],      │
# │                           │                        │                │ ra_dense_2[0][0],      │
# │                           │                        │                │ ga_dense_2[0][0],      │
# │                           │                        │                │ ba_dense_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_21 (Flatten)      │ (None, 7168)           │              0 │ color_concatenation[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_1 (Dense)     │ (None, 1024)           │      7,341,056 │ flatten_21[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_2 (Dense)     │ (None, 512)            │        524,800 │ dense_color_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_3 (Dense)     │ (None, 256)            │        131,328 │ dense_color_2[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_4 (Dense)     │ (None, 128)            │         32,896 │ dense_color_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_5 (Dense)     │ (None, 64)             │          8,256 │ dense_color_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rba_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ rga_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bga_input (InputLayer)    │ (None, 32, 32, 3)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_color_6 (Dense)     │ (None, 32)             │          2,080 │ dense_color_5[0][0]    │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 32,172,000 (122.73 MB)
#  Trainable params: 32,172,000 (122.73 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-d90a3a20261d> in <cell line: 21>()
#      19
#      20 # Train the model
# ---> 21 history = parent_model.fit(
#      22     train_inputs,
#      23     train_labels,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     225                     None,
#     226                 }:
# --> 227                     raise ValueError(
#     228                         f'Input {input_index} of layer "{layer_name}" is '
#     229                         f"incompatible with the layer: expected axis {axis} "
#
# ValueError: Exception encountered when calling Functional.call().
#
# Input 0 of layer "ba_dense_1" is incompatible with the layer: expected axis -1 of input shape to have value 2048, but received input with shape (None, 3072)
#
# Arguments received by Functional.call():
#   • inputs={'rgba_input': 'tf.Tensor(shape=(None, 32, 32, 4), dtype=float32)', 'rg_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'rb_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'gb_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'ra_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'ga_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'ba_input': 'tf.Tensor(shape=(None, 32, 32, 2), dtype=float32)', 'rba_input': 'tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)', 'rga_input': 'tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)', 'bga_input': 'tf.Tensor(shape=(None, 32, 32, 3), dtype=float32)'}
#   • training=True
#   • mask={'rgba_input': 'None', 'rg_input': 'None', 'rb_input': 'None', 'gb_input': 'None', 'ra_input': 'None', 'ga_input': 'None', 'ba_input': 'None', 'rba_input': 'None', 'rga_input': 'None', 'bga_input': 'None'}

# %% [markdown]
# Very practical, right?

# %% [markdown]
# ## What to do once you have a model
#
# Once your model architecture is ready, you will want to:
#
# - Train your model, evaluate it, and run inference. See our
# [guide to training & evaluation with the built-in loops](
#     /guides/training_with_built_in_methods/)
# - Save your model to disk and restore it. See our
# [guide to serialization & saving](/guides/serialization_and_saving/).

# %% [markdown]
# ## Feature extraction with a Sequential model
#
# Once a Sequential model has been built, it behaves like a
# [Functional API model](/guides/functional_api/).
# This means that every layer has an `input`
# and `output` attribute. These attributes can be used to do neat things, like
# quickly creating a model that extracts the outputs of all intermediate layers in a
# Sequential model:

# %%
initial_model = keras.Sequential(
    [
        keras.Input(shape=(250, 250, 3)),
        layers.Conv2D(32, 5, strides=2, activation="relu"),
        layers.Conv2D(32, 3, activation="relu"),
        layers.Conv2D(32, 3, activation="relu"),
    ]
)
feature_extractor = keras.Model(
    inputs=initial_model.inputs,
    outputs=[layer.output for layer in initial_model.layers],
)

# Call feature extractor on test input.
x = ops.ones((1, 250, 250, 3))
features = feature_extractor(x)

# %% [markdown]
# Here's a similar example that only extract features from one layer:

# %%
initial_model = keras.Sequential(
    [
        keras.Input(shape=(250, 250, 3)),
        layers.Conv2D(32, 5, strides=2, activation="relu"),
        layers.Conv2D(32, 3, activation="relu", name="my_intermediate_layer"),
        layers.Conv2D(32, 3, activation="relu"),
    ]
)
feature_extractor = keras.Model(
    inputs=initial_model.inputs,
    outputs=initial_model.get_layer(name="my_intermediate_layer").output,
)
# Call feature extractor on test input.
x = ops.ones((1, 250, 250, 3))
features = feature_extractor(x)

# %% [markdown]
# ## Transfer learning with a Sequential model
#
# Transfer learning consists of freezing the bottom layers in a model and only training
# the top layers. If you aren't familiar with it, make sure to read our [guide
# to transfer learning](/guides/transfer_learning/).
#
# Here are two common transfer learning blueprint involving Sequential models.
#
# First, let's say that you have a Sequential model, and you want to freeze all
# layers except the last one. In this case, you would simply iterate over
# `model.layers` and set `layer.trainable = False` on each layer, except the
# last one. Like this:
#
# ```python
# model = keras.Sequential([
#     keras.Input(shape=(784)),
#     layers.Dense(32, activation='relu'),
#     layers.Dense(32, activation='relu'),
#     layers.Dense(32, activation='relu'),
#     layers.Dense(10),
# ])
#
# # Presumably you would want to first load pre-trained weights.
# model.load_weights(...)
#
# # Freeze all layers except the last one.
# for layer in model.layers[:-1]:
#   layer.trainable = False
#
# # Recompile and train (this will only update the weights of the last layer).
# model.compile(...)
# model.fit(...)
# ```
#
# Another common blueprint is to use a Sequential model to stack a pre-trained
# model and some freshly initialized classification layers. Like this:
#
# ```python
# # Load a convolutional base with pre-trained weights
# base_model = keras.applications.Xception(
#     weights='imagenet',
#     include_top=False,
#     pooling='avg')
#
# # Freeze the base model
# base_model.trainable = False
#
# # Use a Sequential model to add a trainable classifier on top
# model = keras.Sequential([
#     base_model,
#     layers.Dense(1000),
# ])
#
# # Compile & train
# model.compile(...)
# model.fit(...)
# ```
#
# If you do transfer learning, you will probably find yourself frequently using
# these two patterns.

# %% [markdown]
# That's about all you need to know about Sequential models!
#
# To find out more about building models in Keras, see:
#
# - [Guide to the Functional API](/guides/functional_api/)
# - [Guide to making new Layers & Models via subclassing](/guides/making_new_layers_and_models_via_subclassing/)
